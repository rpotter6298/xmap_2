# %%
from classes import *
import pandas as pd

# %%
main_study = xmap_study('data/02_assay_data.xlsx', control_cols=slice(-4, None))
main_study.attach_patient_data(pd.read_excel('data/02_patient_data_cleaned.xlsx', index_col=0))

# %%
main_study.adj_mfi_data.head(3)
# Out:
#    SELE_HPRR2550021  IL6R_HPRR2760260  IQSEC1_HPRR2960328  SELE_HPRR2550018  \
# 1          1.727578        204.727578                 1.0          1.000000
# 2          3.727578          2.727578                 1.0          8.727578
# 3          1.000000          1.000000                 1.0          1.000000
#
#    CFTR_HPRR670001  IL6R_HPRR330033  VAV2_HPRR520084  GLI3_HPRR260114  \
# 1         7.727578         5.727578         6.727578              1.0
# 2         1.000000         8.727578         6.727578              1.0
# 3         1.000000         2.727578         2.727578              1.0
#
#    CAPZA2_HPRR1920128  EEF2_HPRR1510035  ...  CLTCL1_HPRR4290066  \
# 1                 1.0               1.0  ...           30.727578
# 2                 1.0               1.0  ...            1.000000
# 3                 1.0               1.0  ...            2.727578
#
#    TOB2_HPRR4290698  DBNDD1_HPRR4290097  MSANTD4_HPRR4220490  \
# ...

# %%
main_study.patient_data.head(3)
# Out:
#             Age  Sex  Diabetes Hereditary  Hypertension  Migraine  Smoking  \
# Patient ID
# 1            69    0         0        Mor             1         0        0
# 2            73    1         0          0             1         0        0
# 3            80    1         0          0             0         0        0
#
#              VA  Unilateral    SE  ...  MD_3  VFI_3  ROP_Percent  Prog  \
# Patient ID                         ...
# 1           1.0           0  0.25  ... -11.7     72         -5.3     1
# 2           0.9           1  0.50  ...  -7.2     90         -0.8     0
# 3           0.8           1  0.75  ...  -6.2     88         -0.9     0
#
#                              GPA Medicine_Count  SLT  Catop_3  \
# Patient ID
# 1           Possible progression              3    1        0
# 2                 No progression              2    0        0
# 3                 No progression              2    0        0
#
# ...
